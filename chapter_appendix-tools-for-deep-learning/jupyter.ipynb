# %% [markdown]
# <a href="https://colab.research.google.com/github/komalnegi613/git-project1/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= "new delhi is a capital of india and it has lot of universities"
# a.spl
for i in a.split():
  print(i, end="")
# Out:
# newdelhiisacapitalofindiaandithaslotofuniversities

# %%
a= [1,2,3,4,5]
for i in a:
  print(i,a.index(i))
# Out:
# 1 0
# 2 1
# 3 2
# 4 3
# 5 4

# %%
a= [1,3,5, "hello", "9"]
for i in range(0, len(a)):
  if i!=0:
    a[i]="9"
  else:
    a[i]="9"

print(a)
# Out:
# ['9', '9', '9', '9', '9']

# %%
a= [1,5,8,10.5,20.6,19.95]
sum_int=0
sum_float=0

for i in a:
  if type(i)==int:
    sum_int+=i
    #print("int")
  else:
    sum_float+=i
    #print("float")
print(sum_int, sum_float)
# Out:
# 14 51.05
