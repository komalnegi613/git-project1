# %%
def is_palindrome(text):
  text= str(text),lower()

# %%
def is_palindrome(text):

a= "madam"
b= "madam"
b==a
# Out:
# True

# %%
#please create programe for calculator using function and capture all possible featuresSSS

# %%
def function1(a):
  "This function is designed for string palindrome"
  if a==a[::-1]:
    return a[::-1]
    print("yes it is palindrome")
  else:
    print("given string is not a palindrome")

# %%
function1("racecar")
# Out:
# 'racecar'
