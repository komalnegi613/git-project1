# %%
# lambda- function
k= lambda a,b:a+b
k(2,3)
# Out:
# 5

# %%
def div(a,b)
  if b!=0
  return a/b

# %%
lambda a,b:if b!=0: a/b

# %%
k= lambda a,b:a*b
k(2,3)
# Out:
# 6

# %%
lambda x: if a%2=0 print("even")else print("odd")

# %%
lambda x: "even" if x % 2 == 0 else "odd"
# Out:
# <function __main__.<lambda>(x)>

# %%
to_lower= lambda s:s.lower()
print(to_lower("KOMAL"))
# Out:
# komal

# %%
def string(a):
  """this function is designed to handle the case of length,uppercase & lowercase"""
  if type(a)==str:
    print("length of string is", len(a))
    print(a.lower())
    print(a.upper())
  else:
    print("invalid input supplied")


#invalid case--
